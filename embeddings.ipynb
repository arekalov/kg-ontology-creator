# %%
# !pip install tensorflow==2.13.0
# !pip install ampligraph
# !pip install rdflib
# Out:
# Requirement already satisfied: tensorflow==2.13.0 in ./.venv/lib/python3.9/site-packages (2.13.0)
# Requirement already satisfied: tensorflow-macos==2.13.0 in ./.venv/lib/python3.9/site-packages (from tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./.venv/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in ./.venv/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in ./.venv/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (25.9.23)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in ./.venv/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.venv/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in ./.venv/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.14.0)
# Requirement already satisfied: libclang>=13.0.0 in ./.venv/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (18.1.1)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in ./.venv/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.venv/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.4.0)
# Requirement already satisfied: packaging in ./.venv/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./.venv/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (4.25.8)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (44.1.1)
# Requirement already satisfied: six>=1.12.0 in ./.venv/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.venv/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.1.0)
# Collecting typing-extensions<4.6.0,>=3.6.6 (from tensorflow-macos==2.13.0->tensorflow==2.13.0)
#   Using cached typing_extensions-4.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: wrapt>=1.11.0 in ./.venv/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.venv/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.74.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in ./.venv/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in ./.venv/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in ./.venv/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.13.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./.venv/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.13.0->tensorflow==2.13.0) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./.venv/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.43.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in ./.venv/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in ./.venv/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.9)
# Requirement already satisfied: requests<3,>=2.21.0 in ./.venv/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.32.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.1.4)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.venv/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (8.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (2025.11.12)
# Requirement already satisfied: markupsafe>=2.1.1 in ./.venv/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.0.3)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.23.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in ./.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.3.1)
# Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Installing collected packages: typing-extensions
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# exceptiongroup 1.3.1 requires typing-extensions>=4.6.0; python_version < "3.13", but you have typing-extensions 4.5.0 which is incompatible.
# Successfully installed typing-extensions-4.5.0
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: ampligraph in ./.venv/lib/python3.9/site-packages (2.1.0)
# Requirement already satisfied: numpy>=1.14.3 in ./.venv/lib/python3.9/site-packages (from ampligraph) (1.24.3)
# Requirement already satisfied: pytest>=3.5.1 in ./.venv/lib/python3.9/site-packages (from ampligraph) (8.4.2)
# Requirement already satisfied: scikit-learn>=0.19.1 in ./.venv/lib/python3.9/site-packages (from ampligraph) (1.6.1)
# Requirement already satisfied: tqdm>=4.23.4 in ./.venv/lib/python3.9/site-packages (from ampligraph) (4.67.1)
# Requirement already satisfied: pandas>=0.23.1 in ./.venv/lib/python3.9/site-packages (from ampligraph) (2.3.3)
# Requirement already satisfied: sphinx==5.0.2 in ./.venv/lib/python3.9/site-packages (from ampligraph) (5.0.2)
# Requirement already satisfied: myst-parser==0.18.0 in ./.venv/lib/python3.9/site-packages (from ampligraph) (0.18.0)
# Requirement already satisfied: docutils<0.18 in ./.venv/lib/python3.9/site-packages (from ampligraph) (0.17.1)
# Requirement already satisfied: sphinx-rtd-theme==1.0.0 in ./.venv/lib/python3.9/site-packages (from ampligraph) (1.0.0)
# Requirement already satisfied: sphinxcontrib-bibtex==2.4.2 in ./.venv/lib/python3.9/site-packages (from ampligraph) (2.4.2)
# Requirement already satisfied: beautifultable>=0.7.0 in ./.venv/lib/python3.9/site-packages (from ampligraph) (1.1.0)
# Requirement already satisfied: pyyaml>=3.13 in ./.venv/lib/python3.9/site-packages (from ampligraph) (6.0.3)
# Requirement already satisfied: rdflib>=4.2.2 in ./.venv/lib/python3.9/site-packages (from ampligraph) (7.5.0)
# Requirement already satisfied: scipy==1.10.0 in ./.venv/lib/python3.9/site-packages (from ampligraph) (1.10.0)
# Requirement already satisfied: networkx>=2.3 in ./.venv/lib/python3.9/site-packages (from ampligraph) (3.2.1)
# Requirement already satisfied: flake8>=3.7.7 in ./.venv/lib/python3.9/site-packages (from ampligraph) (7.3.0)
# Requirement already satisfied: setuptools>=36 in ./.venv/lib/python3.9/site-packages (from ampligraph) (44.1.1)
# Requirement already satisfied: matplotlib>=3.7 in ./.venv/lib/python3.9/site-packages (from ampligraph) (3.9.4)
# Requirement already satisfied: docopt==0.6.2 in ./.venv/lib/python3.9/site-packages (from ampligraph) (0.6.2)
# Requirement already satisfied: schema==0.7.5 in ./.venv/lib/python3.9/site-packages (from ampligraph) (0.7.5)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from myst-parser==0.18.0->ampligraph) (3.1.6)
# Requirement already satisfied: markdown-it-py<3.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from myst-parser==0.18.0->ampligraph) (2.2.0)
# Requirement already satisfied: mdit-py-plugins~=0.3.0 in ./.venv/lib/python3.9/site-packages (from myst-parser==0.18.0->ampligraph) (0.3.5)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.9/site-packages (from myst-parser==0.18.0->ampligraph) (4.5.0)
# Requirement already satisfied: contextlib2>=0.5.5 in ./.venv/lib/python3.9/site-packages (from schema==0.7.5->ampligraph) (21.6.0)
# Requirement already satisfied: sphinxcontrib-applehelp in ./.venv/lib/python3.9/site-packages (from sphinx==5.0.2->ampligraph) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp in ./.venv/lib/python3.9/site-packages (from sphinx==5.0.2->ampligraph) (2.0.0)
# Requirement already satisfied: sphinxcontrib-jsmath in ./.venv/lib/python3.9/site-packages (from sphinx==5.0.2->ampligraph) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in ./.venv/lib/python3.9/site-packages (from sphinx==5.0.2->ampligraph) (2.1.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in ./.venv/lib/python3.9/site-packages (from sphinx==5.0.2->ampligraph) (2.0.0)
# Requirement already satisfied: sphinxcontrib-qthelp in ./.venv/lib/python3.9/site-packages (from sphinx==5.0.2->ampligraph) (2.0.0)
# Requirement already satisfied: Pygments>=2.0 in ./.venv/lib/python3.9/site-packages (from sphinx==5.0.2->ampligraph) (2.19.2)
# Requirement already satisfied: snowballstemmer>=1.1 in ./.venv/lib/python3.9/site-packages (from sphinx==5.0.2->ampligraph) (3.0.1)
# Requirement already satisfied: babel>=1.3 in ./.venv/lib/python3.9/site-packages (from sphinx==5.0.2->ampligraph) (2.17.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in ./.venv/lib/python3.9/site-packages (from sphinx==5.0.2->ampligraph) (0.7.16)
# Requirement already satisfied: imagesize in ./.venv/lib/python3.9/site-packages (from sphinx==5.0.2->ampligraph) (1.4.1)
# Requirement already satisfied: requests>=2.5.0 in ./.venv/lib/python3.9/site-packages (from sphinx==5.0.2->ampligraph) (2.32.5)
# Requirement already satisfied: packaging in ./.venv/lib/python3.9/site-packages (from sphinx==5.0.2->ampligraph) (25.0)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.9/site-packages (from sphinx==5.0.2->ampligraph) (8.7.0)
# Requirement already satisfied: pybtex>=0.24 in ./.venv/lib/python3.9/site-packages (from sphinxcontrib-bibtex==2.4.2->ampligraph) (0.25.1)
# Requirement already satisfied: pybtex-docutils>=1.0.0 in ./.venv/lib/python3.9/site-packages (from sphinxcontrib-bibtex==2.4.2->ampligraph) (1.0.3)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.9/site-packages (from beautifultable>=0.7.0->ampligraph) (0.2.14)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in ./.venv/lib/python3.9/site-packages (from flake8>=3.7.7->ampligraph) (0.7.0)
# Requirement already satisfied: pycodestyle<2.15.0,>=2.14.0 in ./.venv/lib/python3.9/site-packages (from flake8>=3.7.7->ampligraph) (2.14.0)
# Requirement already satisfied: pyflakes<3.5.0,>=3.4.0 in ./.venv/lib/python3.9/site-packages (from flake8>=3.7.7->ampligraph) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib>=3.7->ampligraph) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib>=3.7->ampligraph) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib>=3.7->ampligraph) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib>=3.7->ampligraph) (1.4.7)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.9/site-packages (from matplotlib>=3.7->ampligraph) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib>=3.7->ampligraph) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.9/site-packages (from matplotlib>=3.7->ampligraph) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib>=3.7->ampligraph) (6.5.2)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas>=0.23.1->ampligraph) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.9/site-packages (from pandas>=0.23.1->ampligraph) (2025.2)
# Requirement already satisfied: exceptiongroup>=1 in ./.venv/lib/python3.9/site-packages (from pytest>=3.5.1->ampligraph) (1.3.1)
# Requirement already satisfied: iniconfig>=1 in ./.venv/lib/python3.9/site-packages (from pytest>=3.5.1->ampligraph) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in ./.venv/lib/python3.9/site-packages (from pytest>=3.5.1->ampligraph) (1.6.0)
# Requirement already satisfied: tomli>=1 in ./.venv/lib/python3.9/site-packages (from pytest>=3.5.1->ampligraph) (2.3.0)
# Requirement already satisfied: isodate<1.0.0,>=0.7.2 in ./.venv/lib/python3.9/site-packages (from rdflib>=4.2.2->ampligraph) (0.7.2)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn>=0.19.1->ampligraph) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn>=0.19.1->ampligraph) (3.6.0)
# Collecting typing-extensions (from myst-parser==0.18.0->ampligraph)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.9/site-packages (from importlib-metadata>=4.4->sphinx==5.0.2->ampligraph) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->myst-parser==0.18.0->ampligraph) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.9/site-packages (from markdown-it-py<3.0.0,>=1.0.0->myst-parser==0.18.0->ampligraph) (0.1.2)
# Requirement already satisfied: latexcodec>=1.0.4 in ./.venv/lib/python3.9/site-packages (from pybtex>=0.24->sphinxcontrib-bibtex==2.4.2->ampligraph) (3.0.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.7->ampligraph) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests>=2.5.0->sphinx==5.0.2->ampligraph) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.9/site-packages (from requests>=2.5.0->sphinx==5.0.2->ampligraph) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.9/site-packages (from requests>=2.5.0->sphinx==5.0.2->ampligraph) (2.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.9/site-packages (from requests>=2.5.0->sphinx==5.0.2->ampligraph) (2025.11.12)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: typing-extensions
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-macos 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.15.0 which is incompatible.
# Successfully installed typing-extensions-4.15.0
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: rdflib in ./.venv/lib/python3.9/site-packages (7.5.0)
# Requirement already satisfied: isodate<1.0.0,>=0.7.2 in ./.venv/lib/python3.9/site-packages (from rdflib) (0.7.2)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in ./.venv/lib/python3.9/site-packages (from rdflib) (3.2.5)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import ampligraph
import tensorflow as tf
from rdflib import Graph

# %%
owl_file_name = "/Users/m.s.taranenko/PyCharmMiscProject/wot_with_data.owl"
g = Graph()
g.parse(owl_file_name)

# Извлекаем все триплеты
triplets = []
for subj, pred, obj in g:
  triplets.append((
    str(subj),
    str(pred),
    str(obj)
  ))

# Создаем DataFrame
df = pd.DataFrame(triplets, columns=['subject', 'predicate', 'object'])

print(f"Успешно извлечено {len(df)} триплетов")
# Out:
# Успешно извлечено 31115 триплетов

# %%
from ampligraph.evaluation import train_test_split_no_unseen

X_train, X_valid = train_test_split_no_unseen(np.array(df), test_size=3000)

# %%
print('Train set size: ', X_train.shape)
print('Test set size: ', X_valid.shape)
# Out:
# Train set size:  (28115, 3)
# Test set size:  (3000, 3)

# %%
from ampligraph.latent_features import ScoringBasedEmbeddingModel
from ampligraph.latent_features.loss_functions import get as get_loss
from ampligraph.latent_features.regularizers import get as get_regularizer

model = ScoringBasedEmbeddingModel(k=100,
                                   eta=20,
                                   scoring_type='ComplEx',
                                   seed=0)

loss = get_loss('multiclass_nll')

model.compile(optimizer="adam", loss=loss)

# %%
model.fit(X_train,
          batch_size=int(X_train.shape[0] / 50),
          epochs=300, # Number of training epochs
          verbose=True # Displays a progress bar.
          )
# Out:
# Epoch 1/300
# 52/52 [==============================] - 1s 16ms/step - loss: 1678.3512
# Epoch 2/300
# 52/52 [==============================] - 1s 11ms/step - loss: 
# 52/52 [==============================] - 1s 11ms/step - loss: 113.9571
# Epoch 273/300
# 52/52 [==============================] - 1s 12ms/step - loss: 113.7919
# Epoch 274/300
# 52/52 [==============================] - 1s 11ms/step - loss: 113.6220
# Epoch 275/300
# 52/52 [==============================] - 1s 11ms/step - loss: 113.4556
# Epoch 276/300
# 52/52 [==============================] - 1s 11ms/step - loss: 113.2941
# Epoch 277/300
# 52/52 [==============================] - 1s 11ms/step - loss: 113.1369
# Epoch 278/300
# 52/52 [==============================] - 1s 11ms/step - loss: 112.9788
# Epoch 279/300
# 52/52 [==============================] - 1s 11ms/step - loss: 112.8193
# Epoch 280/300
# 52/52 [==============================] - 1s 11ms/step - loss: 112.6650
# Epoch 281/300
# 52/52 [==============================] - 1s 11ms/step - loss: 112.5069
# Epoch 282/300
# 52/52 [==============================] - 1s 12ms/step - loss: 112.3549
# Epoch 283/300
# 52/52 [==============================] - 1s 12ms/step - loss: 112.2058
# Epoch 284/300
# 52/52 [==============================] - 1s 12ms/step - loss: 112.0559
# Epoch 285/300
# 52/52 [==============================] - 1s 11ms/step - loss: 111.9066
# Epoch 286/300
# 52/52 [==============================] - 1s 12ms/step - loss: 111.7617
# Epoch 287/300
# 52/52 [==============================] - 1s 12ms/step - loss: 111.6174
# Epoch 288/300
# 52/52 [==============================] - 1s 11ms/step - loss: 111.4684
# Epoch 289/300
# 52/52 [==============================] - 1s 11ms/step - loss: 111.3226
# Epoch 290/300
# 52/52 [==============================] - 1s 11ms/step - loss: 111.1719
# Epoch 291/300
# 52/52 [==============================] - 1s 12ms/step - loss: 111.0244
# Epoch 292/300
# 52/52 [==============================] - 1s 11ms/step - loss: 110.8845
# Epoch 293/300
# 52/52 [==============================] - 1s 11ms/step - loss: 110.7400
# Epoch 294/300
# 52/52 [==============================] - 1s 11ms/step - loss: 110.5911
# Epoch 295/300
# 52/52 [==============================] - 1s 12ms/step - loss: 110.4502
# Epoch 296/300
# 52/52 [==============================] - 1s 11ms/step - loss: 110.3120
# Epoch 297/300
# 52/52 [==============================] - 1s 11ms/step - loss: 110.1703
# Epoch 298/300
# 52/52 [==============================] - 1s 11ms/step - loss: 110.0268
# Epoch 299/300
# 52/52 [==============================] - 1s 11ms/step - loss: 109.8918
# Epoch 300/300
# 52/52 [==============================] - 1s 11ms/step - loss: 109.7514

# %%
ranks = model.evaluate(X_valid,
                      use_filter={'train': X_train,
                                  'test': X_valid},
                      corrupt_side='s,o',
                      verbose=True)
# Out:
#      18/Unknown - 0s 22ms/stepConnection closed unexpectedly!
# Connection closed unexpectedly!
# 301/301 [==============================] - 3s 10ms/step

# %%
from ampligraph.evaluation import mr_score, mrr_score, hits_at_n_score

mr = mr_score(ranks)
mrr = mrr_score(ranks)

print("MRR: %.2f" % (mrr))
print("MR: %.2f" % (mr))

hits_10 = hits_at_n_score(ranks, n=10)
print("Hits@10: %.2f" % (hits_10))
hits_3 = hits_at_n_score(ranks, n=3)
print("Hits@3: %.2f" % (hits_3))
hits_1 = hits_at_n_score(ranks, n=1)
print("Hits@1: %.2f" % (hits_1))
# Out:
# MRR: 0.42
# MR: 629.90
# Hits@10: 0.57
# Hits@3: 0.46
# Hits@1: 0.34

# %% [markdown]
# # Разбиение по нациям

# %%
def import_tanks_from_wot_data_as_dataframe():
    import pandas as pd
    from pathlib import Path


    wot_data_file = "wot_data.csv"

    # Читаем данные
    df = pd.read_csv(wot_data_file, sep=';')
    print(f"Loaded {len(df)} tank configurations")

    # Маппинг типа → роль (как в оригинальной функции)
    def get_role_name_from_type(tank_type):
        role_map = {
            'HeavyTank': 'HeavyAssault',
            'MediumTank': 'Support',
            'LightTank': 'Scout',
            'SPG': 'Artillery',
            'AT-SPG': 'Sniper'
        }
        return role_map.get(tank_type, 'General')

    tanks_unique = df.groupby('name').first().reset_index()
    tank_data = []

    for idx, row in tanks_unique.iterrows():
        tank_name = row['name'].strip()

        # Базовые атрибуты
        tank_dict = {
            'name': tank_name,
            'tier': pd.to_numeric(row.get('tier'), errors='coerce'),
            'nation': row.get('nation'),
            'type': row.get('type', 'Tank'),
            'is_premium': bool(row.get('is_premium', False)),
            'is_wheeled': bool(row.get('is_wheeled', False)),
            'is_gift': bool(row.get('is_gift', False)),
            'short_name': row.get('short_name'),
            'price_credit': pd.to_numeric(row.get('price_credit'), errors='coerce'),
            'price_gold': pd.to_numeric(row.get('price_gold'), errors='coerce'),
        }

        # Характеристики
        tank_dict.update({
            'hp': pd.to_numeric(row.get('hp'), errors='coerce'),
            'hull_hp': pd.to_numeric(row.get('hull_hp'), errors='coerce'),
            'weight': pd.to_numeric(row.get('weight'), errors='coerce'),
            'hull_weight': pd.to_numeric(row.get('hull_weight'), errors='coerce'),
            'speed_forward': pd.to_numeric(row.get('speed_forward'), errors='coerce'),
            'speed_backward': pd.to_numeric(row.get('speed_backward'), errors='coerce'),
            'ammo.avg_damage': pd.to_numeric(row.get('ammo.avg_damage'), errors='coerce'),
            'ammo.avg_penetration': pd.to_numeric(row.get('ammo.avg_penetration'), errors='coerce'),
            'dpm': pd.to_numeric(row.get('dpm'), errors='coerce'),
            'gun.fire_rate': pd.to_numeric(row.get('gun.fire_rate'), errors='coerce'),
            'gun.aim_time': pd.to_numeric(row.get('gun.aim_time'), errors='coerce'),
        })

        # Роль на основе типа
        tank_dict['role'] = get_role_name_from_type(tank_dict['type'])

        # ID модулей (для возможной агрегации позже)
        tank_dict.update({
            'gun_id': row.get('gun'),
            'engine_id': row.get('engine'),
            'turret_id': row.get('turret'),
            'suspension_id': row.get('suspension'),
            'radio_id': row.get('radio'),
        })

        tank_data.append(tank_dict)


    result_df = pd.DataFrame(tank_data)

    # Необязательно: удаляем строки с пропущенным именем
    result_df = result_df.dropna(subset=['name']).reset_index(drop=True)

    return result_df

# %%
df_tanks = import_tanks_from_wot_data_as_dataframe()
# Out:
# ============================================================
# IMPORTING TANK DATA FROM wot_data.csv → DATAFRAME
# ============================================================
# Loaded 14691 tank configurations
# Creating unique tank entries...
# Unique tanks: 708
#   Processed 100/708 tanks
#   Processed 200/708 tanks
#   Processed 300/708 tanks
#   Processed 400/708 tanks
#   Processed 500/708 tanks
#   Processed 600/708 tanks
#   Processed 700/708 tanks
# ✅ Created DataFrame with 708 unique tanks
#    Columns: ['name', 'tier', 'nation', 'type', 'is_premium', 'is_wheeled', 'is_gift', 'short_name', 'price_credit', 'price_gold', 'hp', 'hull_hp', 'weight', 'hull_weight', 'speed_forward', 'speed_backward', 'ammo.avg_damage', 'ammo.avg_penetration', 'dpm', 'gun.fire_rate', 'gun.aim_time', 'role', 'gun_id', 'engine_id', 'turret_id', 'suspension_id', 'radio_id']

# %%
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score

tanks = df_tanks['name'].values
y_true = df_tanks.set_index('name').loc[tanks, 'type'].values

X = model.get_embeddings(tanks)

X_scaled = StandardScaler().fit_transform(X)

pca = PCA(n_components=0.90, random_state=42)
X_pca = pca.fit_transform(X_scaled)


k = 10

kmeans = KMeans(
    n_clusters=k,
    n_init=50,
    max_iter=500,
    random_state=42
)

clusters = kmeans.fit_predict(X_pca)

arc = adjusted_rand_score(y_true, clusters)

print(f"ARS : {arc:.3f}")

pca_2d = PCA(n_components=2, random_state=42)
X_2d = pca_2d.fit_transform(X_scaled)


plot_df = pd.DataFrame({
    "name": tanks,
    "x": X_2d[:, 0],
    "y": X_2d[:, 1],
    "type": y_true,
    "cluster": clusters
})

def plot_embeddings(
    df,
    hue,
    title,
    label_frac=0.05,
    figsize=(14, 10)
):
    np.random.seed(42)
    plt.figure(figsize=figsize)

    ax = sns.scatterplot(
        data=df,
        x="x",
        y="y",
        hue=hue,
        palette="tab10" if df[hue].nunique() <= 10 else "tab20",
        s=110,
        alpha=0.8,
        edgecolor="black",
        linewidth=0.4
    )

    texts = []

    if hue == "cluster":
        centers = df.groupby("cluster")[["x", "y"]].mean().reset_index()
        for _, c in centers.iterrows():
            nearest = df.iloc[
                ((df["x"] - c["x"])**2 + (df["y"] - c["y"])**2).idxmin()
            ]
            texts.append(
                plt.text(nearest["x"], nearest["y"], nearest["name"],
                         fontsize=9, fontweight="bold")
            )

    sample = df.sample(frac=label_frac, random_state=42)
    for _, row in sample.iterrows():
        texts.append(
            plt.text(row["x"], row["y"], row["name"], fontsize=8)
        )

    adjust_text(
        texts,
        arrowprops=dict(arrowstyle="-", color="gray", lw=0.5),
        force_text=0.5,
        expand_points=(1.2, 1.2)
    )

    plt.title(title, fontsize=16)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

plot_embeddings(
    plot_df,
    hue="type",
    title="PCA 2D — цвет: истинный тип танка"
)

plot_embeddings(
    plot_df,
    hue="cluster",
    title="PCA 2D — цвет: кластер (k = 10)"
)
# Out:
# Embeddings shape: (708, 200)
# PCA dim: 131
# Explained variance: 0.902
# ARС (k=10): 0.107

# %% [markdown]
# # Классификация

# %%
# !pip uninstall -y xgboost
# !pip install xgboost
# Out:
# Found existing installation: xgboost 2.1.4
# Uninstalling xgboost-2.1.4:
#   Successfully uninstalled xgboost-2.1.4
# Collecting xgboost
#   Using cached xgboost-2.1.4-py3-none-macosx_12_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in ./.venv/lib/python3.9/site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in ./.venv/lib/python3.9/site-packages (from xgboost) (1.10.0)
# Using cached xgboost-2.1.4-py3-none-macosx_12_0_arm64.whl (1.9 MB)
# Installing collected packages: xgboost
# Successfully installed xgboost-2.1.4
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder

# %%
# Сущности
tanks = df_tanks['name'].values

X = model.get_embeddings(tanks)

y_raw = df_tanks.set_index('name').loc[tanks, 'type'].values

label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y_raw)

print("Classes:", label_encoder.classes_)
# Out:
# Classes: ['AT-SPG' 'SPG' 'heavyTank' 'lightTank' 'mediumTank']
# X shape: (708, 200)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=42,
    stratify=y
)
# Out:
# Train size: 531
# Test size: 177

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

xgb_model = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.9,
    colsample_bytree=0.9,
    objective="multi:softmax",
    num_class=len(label_encoder.classes_),
    random_state=42,
    eval_metric="mlogloss"
)

xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)

acc_xgb = accuracy_score(y_test, y_pred)
print(f"XGBoost accuracy (KG embeddings): {acc_xgb:.3f}")
# Out:
# XGBoost accuracy (KG embeddings): 0.785

# %%
from collections import Counter

most_common_class = Counter(y_train).most_common(1)[0][0]
y_pred_base = np.full_like(y_test, most_common_class)

acc_base = accuracy_score(y_test, y_pred_base)
print(f"Baseline (most frequent class) accuracy: {acc_base:.3f}")
# Out:
# Baseline (most frequent class) accuracy: 0.299

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

df_features = df_tanks.set_index('name').loc[tanks][['nation', 'tier', 'role']]

X_train_feat, X_test_feat, y_train_feat, y_test_feat = train_test_split(
    df_features,
    y,
    test_size=0.25,
    random_state=42,
    stratify=y
)

categorical_features = ['nation', 'role']
numeric_features = ['tier']

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features),
        ('num', 'passthrough', numeric_features)
    ]
)

baseline_model = Pipeline([
    ('preprocess', preprocessor),
    ('clf', LogisticRegression(max_iter=1000))
])

baseline_model.fit(X_train_feat, y_train_feat)

y_pred_oh = baseline_model.predict(X_test_feat)
acc_oh = accuracy_score(y_test_feat, y_pred_oh)

print(f"Baseline (one-hot features) accuracy: {acc_oh:.3f}")
# Out:
# Baseline (one-hot features) accuracy: 0.650

# %% [markdown]
# # Предсказание ссылок (с tank на конце)

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
# Все сущности типа tank
tank_entities = set(df_tanks['name'].values)

# %%
ranks = []

def evaluate_triple_rank(model, triple, tank_entities):
    h, r, t_true = triple

    # Генерируем негативные tail-сущности
    negative_tails = list(tank_entities - {t_true})

    # Формируем негативные триплеты
    negative_triples = np.array([[h, r, t] for t in negative_tails])

    # Полный список: истинный + негативные
    all_triples = np.vstack([
        np.array([[h, r, t_true]]),
        negative_triples
    ])

    # Получаем score модели
    scores = model.predict(all_triples)

    # Сортировка по убыванию score
    ranked_indices = np.argsort(scores)[::-1]

    # Ранг истинного триплета (позиция +1)
    rank = np.where(ranked_indices == 0)[0][0] + 1

    return rank

for triple in tqdm(X_valid):
    h, r, t = triple
    if t in tank_entities:
        rank = evaluate_triple_rank(model, triple, tank_entities)
        ranks.append(rank)

ranks = np.array(ranks)
# Out:
# 100%|██████████| 3000/3000 [00:04<00:00, 658.00it/s]

# %%
mr = ranks.mean()
print(f"MR: {mr:.2f}")

mrr = np.mean(1.0 / ranks)
print(f"MRR: {mrr:.3f}")

def hits_at_n(ranks, n):
    return np.mean(ranks <= n)

for n in [1, 3, 10]:
    print(f"Hits@{n}: {hits_at_n(ranks, n):.3f}")
# Out:
# MR: 20.25
# MRR: 0.845
# Hits@1: 0.767
# Hits@3: 0.922
# Hits@10: 0.957

# %% [markdown]
# # Предсказание ссылок (hasType)

# %%
ranks = []

types = {"http://www.semanticweb.org/ontology/wot#SelfPropelledGun",
         "http://www.semanticweb.org/ontology/wot#HeavyTank",
         "http://www.semanticweb.org/ontology/wot#MediumTank",
         "http://www.semanticweb.org/ontology/wot#LightTank",
         "http://www.semanticweb.org/ontology/wot#TankDestroyer"}


def evaluate_triple_rank(model, triple):
    h, r, t_true = triple

    # Генерируем негативные tail-сущности
    negative_tails = list(types - {t_true})

    # Формируем негативные триплеты
    negative_triples = np.array([[h, r, t] for t in negative_tails])

    # Полный список: истинный + негативные
    all_triples = np.vstack([
        np.array([[h, r, t_true]]),
        negative_triples
    ])

    # Получаем score модели
    scores = model.predict(all_triples)

    # Сортировка по убыванию score
    ranked_indices = np.argsort(scores)[::-1]

    # Ранг истинного триплета (позиция +1)
    rank = np.where(ranked_indices == 0)[0][0] + 1

    return rank


for triple in tqdm(X_valid):
    h, r, t = triple
    if t in types:
        rank = evaluate_triple_rank(model, triple)
        ranks.append(rank)

ranks = np.array(ranks)

mr = ranks.mean()
print(f"MR: {mr:.2f}")

mrr = np.mean(1.0 / ranks)
print(f"MRR: {mrr:.3f}")


def hits_at_n(ranks, n):
    return np.mean(ranks <= n)


for n in [1, 3, 10]:
    print(f"Hits@{n}: {hits_at_n(ranks, n):.3f}")
# Out:
# 100%|██████████| 3000/3000 [00:00<00:00, 15666.78it/s]
# MR: 1.00
# MRR: 1.000
# Hits@1: 1.000
# Hits@3: 1.000
# Hits@10: 1.000
